# %%
stock = {
    'pains au chocolat':500,
    'croissants':400,
    'baguettes':500,
    'beignets':200
}

# %%
for i in stock.keys():
    print(f"{i} : {stock[i]}")
# Out:
# pains au chocolat : 500
# croissants : 400
# baguettes : 500
# beignets : 200
